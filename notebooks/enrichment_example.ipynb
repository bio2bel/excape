# %%
from pybel.examples import statin_graph
from pybel_jupyter import to_jupyter
from bio2bel_excape import Manager

manager = Manager()
manager.enrich_targets(statin_graph)

to_jupyter(statin_graph)
# Out:
# Skiping target HMGCR
# Skiping target 1.1.1.34
# Skiping target 1.1.1.88
